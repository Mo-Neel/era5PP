# %%
# Import the library and its functions
import xarray as xr
from era5pplib.functions import shp, layerplt, clip, avgclip, nc4aggr, resdaily, rh, W_velocity

# %%
era52000 = xr.open_dataset('Era5_seperate_Years\era52000.nc')

# %%
shp("Basin Boundary/basin.shp", "boundary")
# Out:
# <Axes: >

# %%
layerplt(era52000.isel(time = 0).t2m, "Basin Boundary/basin.shp")

# %%
clip_shp = clip(era52000, "EPSG:32636", "shapefile", "Basin Boundary/basin.shp")

# %%
clip_shp.isel(time = 0).t2m.plot()

# %%
clip_geo = clip(era52000, "EPSG:32636", "geometry", [38,10,40, 12])

# %%
clip_geo.isel(time = 0).t2m.plot()

# %%
avgclip(clip_geo, 't2m','clip_geo')

# %%
nc4aggr('C:/Users/Hp/Downloads/ERA5python/era5years', (1,21), 'Y_aggregated')

# %%
Y_aggregated = xr.open_dataset('Y_aggregated')

# %%
Y_aggregated
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 25, latitude: 23, time: 184104)
# Coordinates:
#   * longitude  (longitude) float32 34.0 34.25 34.5 34.75 ... 39.5 39.75 40.0
#   * latitude   (latitude) float32 12.9 12.65 12.4 12.15 ... 8.15 7.9 7.65 7.4
#   * time       (time) datetime64[ns] 2000-01-01 ... 2020-12-31T23:00:00
# Data variables:
#     u10        (time, latitude, longitude) float32 ...
#     v10        (time, latitude, longitude) float32 ...
#     d2m        (time, latitude, longitude) float32 ...
#     t2m        (time, latitude, longitude) float32 ...
#     ssrc       (time, latitude, longitude) float32 ...
#     sp         (time, latitude, longitude) float32 ...
#     tp         (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-07-18 06:34:36 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
resdaily('meanvars.nc', 'mean', 'daiy_avgvars.nc')

# %%
resdaily('sumvars.nc', 'sum', 'daiy_sumvars.nc')

# %%
rh('Era5_Daily_Data\DailyMean_t2m.nc', 't2m', 'Era5_Daily_Data\DailyMean_d2m.nc', 'd2m','DailyMean_RH.nc')

# %%
W_velocity('Era5_Daily_Data\DailyMean_u10.nc', 'u10', 'Era5_Daily_Data\DailyMean_v10.nc', 'v10', 'DailyMean_WS')
# Out:
# C:\Users\Hp\Downloads\ERA5python\era5PP\era5env\lib\site-packages\xarray\backends\plugins.py:71: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
